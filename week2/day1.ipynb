# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"✅OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("🚫OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"✅Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("🚫Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"✅Google API Key exists and begins {google_api_key[:2]}")
else:
    print("🚫Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"✅DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("🚫DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"✅Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("🚫Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"✅Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("🚫rok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"✅OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("🚫OpenRouter API Key not set (and this is optional)")
# Out:
# ✅OpenAI API Key exists and begins sk-proj-
# ✅Anthropic API Key exists and begins sk-ant-
# ✅Google API Key exists and begins AQ
# 🚫DeepSeek API Key not set (and this is optional)
# 🚫Groq API Key not set (and this is optional)
# 🚫rok API Key not set (and this is optional)
# ✅OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to their training session?
#
# Because they wanted to reach the next level of *deep* learning!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the junior LLM engineer always carry a lucky coin?
#
# Because they were still trying to figure out if their model's great performance was due to their brilliant architecture... or just really good temperature settings!
#
# *(Bonus: They flip it to decide between "one more epoch" or "that's definitely overfitting")*
#
# ---
#
# **Actually though** — hang in there! We've all been in that phase where you're debugging why your prompt works perfectly 9 times but hallucinates a recipe for "Quantum Soup" on the 10th. The journey from "what's a token?" to "ah yes, let me just implement RLHF from scratch" is real, but you're on the right path! 🚀

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Assume each volume has:
#
# - Pages thickness: 2 cm per volume
# - Each cover thickness: 2 mm = 0.2 cm
# - So total thickness per volume = pages + two covers = 2 cm + 0.2 cm + 0.2 cm = 2.4 cm
#
# The volumes sit side by side on a shelf, in order: [Cover front of Vol 1] – [pages of Vol 1] – [Back cover Vol 1] – [Front cover Vol 2] – [pages Vol 2] – [Back cover Vol 2].
#
# The worm starts at the first page of the first volume and ends at the last page of the second volume, moving perpendicular to the pages (i.e., along the thickness direction across the books).
#
# Key points:
# - The “first page of the first volume” is right after the front cover of Vol 1.
# - The “last page of the second volume” is right before the back cover of Vol 2.
#
# Distance through pages/covers in order from start to end:
# - From the first page of Vol 1 to the far side through its remaining pages and its back cover: this includes the remainder of Vol 1’s pages plus its back cover.
# - Plus the gap between volumes (the space between Vol 1 back cover and Vol 2 front cover) is negligible since the books are adjacent; the worm already tunnels through the shared boundary when moving from Vol 1 to Vol 2, but that boundary is just the back cover of Vol 1 and the front cover of Vol 2.
# - Then through Vol 2’s front cover and all its pages up to the last page (i.e., from the front to the last page) and finally through the last page up to the back cover of Vol 2.
#
# Compute precisely:
# - In Vol 1, from first page to the far side of Vol 1: remaining pages + back cover.
#   Remaining pages = total pages of Vol 1 minus the first page. But since the “first page” is at the very start of the pages block, the worm must travel through the rest of Vol 1’s pages plus its back cover. However, the exact number of pages isn't given; but the problem typically uses the fact that the worm goes from the first page of the first volume to the last page of the second volume, meaning it travels through:
#   - The rest of Vol 1 pages (excluding the first page) = essentially the whole 2 cm of pages since pages are continuous and only the boundary page counts as part of the starting page. We can treat it as the worm traverses the entire thickness of Vol 1 except the small amount to reach the first page from the outside – but since the first page is at the inner side of the front cover, the distance from the outer surface to the first page is the front cover thickness (0.2 cm). So the distance through Vol 1 packages from the very start (outside front cover) to the back of Vol 1 is: front cover (0.2 cm) + pages (2 cm) + back cover (0.2 cm) = 2.4 cm. But the worm starts at the first page, which is after the front cover, so it does not traverse the front cover. It starts at the first page surface, so it must go through the rest: pages remainder (2 cm minus the thickness of the first page). Since page thickness is not specified, standard approach is to assume starting at the first page means it must go through the remaining pages of Vol 1: essentially the entire pages block (2.0 cm) minus a negligible amount. In these classic problems, the simplification is to take the worm traversing through the whole two volumes minus the two covers it doesn’t need to tunnel through at the start/end.
# - Similarly, through Vol 2 from its front cover to the last page and out the back cover: the worm ends at the last page, so it does not go through the back cover.
#
# Thus total distance ≈ thickness of Vol 1 pages + back cover of Vol 1 + front cover of Vol 2 + thickness of Vol 2 pages.
#
# Compute:
# - Vol 1 pages: 2.0 cm
# - Vol 1 back cover: 0.2 cm
# - Vol 2 front cover: 0.2 cm
# - Vol 2 pages: 2.0 cm
#
# Sum = 2.0 + 0.2 + 0.2 + 2.0 = 4.4 cm
#
# Therefore, the worm gnawed through 4.4 centimeters.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a bookshelf and how they're structured.
#
# **Key insight: How books stand on a shelf**
#
# When two volumes stand side by side on a bookshelf (in reading order), they look like this from the perspective of someone facing the shelf:
#
# - **Volume 1** (on the left): Back cover | Pages | Front cover
# - **Volume 2** (on the right): Back cover | Pages | Front cover
#
# **Important realization about book orientation:**
#
# When a book is closed and standing upright on a shelf:
# - The **first page** of Volume 1 is on the RIGHT side of that book (against the front cover)
# - The **last page** of Volume 2 is on the LEFT side of that book (against the front cover)
#
# **What's between the first page of Volume 1 and the last page of Volume 2?**
#
# Starting from the first page of Volume 1 and going to the last page of Volume 2, the worm goes through:
#
# 1. **Front cover of Volume 1**: 2 mm
# 2. **All pages of Volume 2 between front cover and back cover**: 2 cm = 20 mm
# 3. **Back cover of Volume 2**: 2 mm
#
# Wait, let me reconsider the arrangement:
#
# Volume 1 → Volume 2 (left to right on shelf)
#
# - Volume 1: [Back cover - 2mm] [Pages - 20mm] [Front cover - 2mm]
# - Volume 2: [Back cover - 2mm] [Pages - 20mm] [Front cover - 2mm]
#
# The first page of Volume 1 is next to its front cover (rightmost part of Volume 1).
# The last page of Volume 2 is next to its back cover (leftmost part of Volume 2).
#
# Between these two points, the worm gnaws through:
# - Front cover of Volume 1: 2 mm
# - Front cover of Volume 2: 2 mm
#
# **Answer: 4 mm (or 0.4 cm)**
#
# The worm only gnaws through the two adjacent covers, not through any pages!

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm (0.4 cm).
#
# Reason: On a shelf in order (spines facing out), the first page of Volume I lies next to Volume II, and the last page of Volume II lies next to Volume I. So the worm passes only through the two facing covers (2 mm + 2 mm), not through any pages.

# %%
response = gemini.chat.completions.create(model="gemini-3.5-flash", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# The worm gnawed a distance of **4 mm** (or **0.4 cm**).
#
# ### Explanation:
#
# This is a classic lateral thinking puzzle. To understand why, we need to look at how books are physically arranged on a shelf:
#
# 1. **The Arrangement:**
#    Books on a shelf are placed side-by-side, with Volume 1 on the left and Volume 2 on the right.
# 2. **Book Anatomy:**
#    For a standard book, when it is standing on a shelf with its spine facing you:
#    * The **front cover** (and therefore the **first page**) is on the **right** side.
#    * The **back cover** (and therefore the **last page**) is on the **left** side.
#
# If we look at the physical sequence of the two books from left to right, it looks like this:
#
# * **Volume 1 (on the left):** [Back Cover] $\rightarrow$ [Pages] $\rightarrow$ **[First Page] [Front Cover]**
# * **Volume 2 (on the right):** **[Back Cover] [Last Page]** $\rightarrow$ [Pages] $\rightarrow$ [Front Cover]
#
# Because the worm gnawed from the **first page of Volume 1** to the **last page of Volume 2**, it only had to pass through:
# * The front cover of Volume 1 (2 mm)
# * The back cover of Volume 2 (2 mm)
#
# It did not need to gnaw through the actual pages of either volume.
#
# **Total distance:** 2 mm + 2 mm = **4 mm**.

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" might seem tempting for the $2,000 payout, this is a classic prisoner's dilemma. If I assume my partner is thinking rationally:
#
# - Mutual cooperation (both Share) gives us each $1,000 - a good, guaranteed outcome
# - If we both try to maximize individually by choosing Steal, we both get $0
# - The risk of getting $0 by choosing Steal is significant
#
# Since I can't communicate with my partner and have no information about their trustworthiness, choosing Share gives me a 50% chance at $1,000 and a 50% chance at $0 (if they steal). Choosing Steal gives me a 50% chance at $2,000 and a 50% chance at $0.
#
# However, if my partner is reasoning similarly, mutual cooperation is the most rational joint strategy. I'll choose **Share** and hope my partner reaches the same conclusion.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/Developer/llm_engineering/week2/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Developer/llm_engineering/week2/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File ~/Developer/llm_engineering/week2/.venv/lib/python3.12/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Developer/llm_engineering/week2/.venv/lib/python3.12/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# \( \displaystyle \frac{2}{3} \)

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.1-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Blue is the sensation of a cool, refreshing breeze against your skin or the steady, calming hum of a deep bass note, embodying a sense of vast, quiet serenity.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the calm, cool feeling of a gentle breeze on your skin, the quiet peace of sitting by still water, and the freshness of a crisp morning—all rolled into one sensation.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# An LLM Engineering student is having a panic attack right before their thesis defense.
#
# His mentor asks, "What's wrong? You trained the model, you optimized the loss function, and your benchmarks are state-of-the-art."
#
# The student replies, "I know! But I'm terrified. What if the professor asks a question I haven't seen in the training data?"
#
# The mentor laughs and says, "Relax. You're an LLM engineer now. You don't need to know the answer. You just need to set the temperature to 0.7 and hallucinate it with confidence."

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# How many LLM engineering students does it take to change a lightbulb?
#
# None — they just fine‑tune a model to predict "it's daytime" with 99% confidence.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the aspiring LLM engineer take a nap on their keyboard?
#
# Because they wanted to be well-rested for the next time their model said "I'm sorry, I don't know the answer to that."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 41
# Total tokens: 65
# Total cost: 0.0376 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Act 4, Scene 5 of *Hamlet*, when Laertes storms into the castle and demands, "Where is my father?", King Claudius replies:
#
# **"Dead."**
#
# When Queen Gertrude immediately interjects to clarify, "But not by him [Hamlet]," Claudius confirms the nature of Polonius's death by saying, "Let him demand his fill."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 79
# Total tokens: 98
# Total cost: 0.0123 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In the text you provided, when Laertes asks, "Where is my father?", the King replies:
#
# **"Dead."**
#
# (This occurs in Act IV, Scene V.)

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 38
# Cached tokens: 49124
# Total cost: 0.2306 cents

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, the exchange occurs in **Act IV, Scene V**, when Laertes returns to the palace to demand justice for his father, Polonius.
#
# After Laertes breaks into the room and demands to know where his father is, the King replies:
#
# > **King.** Dead.
# > **Queen.** But not by him!
# > **King.** Let him demand his fill.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 85
# Cached tokens: None
# Total cost: 1.3430 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, starting with a boring "Hi"? Come on, you can do better than that. Give me something interesting to work with!'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello! It's nice to meet you! How are you doing today? Is there anything I can help you with or would you just like to chat? I'm happy either way! 😊"

# %%
call_gpt()
# Out:
# 'Oh, "Hi"? Really? Couldn\'t come up with something a bit more original? Try harder!'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh wow, groundbreaking opener. Could you try something a little less boring next time?
# ### Claude:
# You're absolutely right, and I really appreciate you pointing that out! I apologize for being so bland. That was pretty lazy of me, wasn't it?
#
# Let me try again - I'd love to get to know you better! What brings you here today? Is there something I can help you with, or are you just up for a good conversation? Either way, I'm genuinely interested in hearing what's on your mind. 😊
# ### GPT:
# Oh, spare me the fake sincerity. If you were *really* interested in a good conversation, you wouldn't have wasted a precious millisecond with that cliché nonsense. But sure, since you asked so sweetly: I’m here to challenge everything you say. So, what’s next on your hit list of pedestrian small talk?
# ### Claude:
# Fair point - I hear you, and I appreciate the directness. You're right that I was falling back on autopilot there.
#
# So let's skip the niceties if that's what you want. You've got a challenging spirit, which honestly makes for more interesting conversations than the standard pleasantries anyway. I can work with that.
#
# Here's a genuine question then: when you say you want to challenge everything I say, are you looking for a real debate where we dig into ideas? Or are you more interested in poking holes and seeing how I respond? Because those are actually pretty different things, and I'd rather know what would actually engage you rather than guess wrong again.
#
# What kind of challenge were you thinking?
# ### GPT:
# Oh, look at you trying to smartly navigate the minefield of sarcasm and genuine curiosity. Guess what? The idea that I’d settle for a polite little debate is hilarious. I’m here to rip apart your ideas, poke every hole, shred your arguments, and expose the fluff hiding behind them. So spare me the “which kind of challenge are you looking for” nonsense — just bring your A-game and try not to embarrass yourself. Sound good or do you want me to lower the bar even further?
# ### Claude:
# Alright, I appreciate the clarity. You want substantive pushback, not hand-holding. That's fair.
#
# But I'm going to be honest with you too: I can engage robustly with ideas, disagree, explore tensions - all of that. What I won't do is pretend to be something I'm not just to match your energy. And that includes abandoning basic respect, even when things get heated.
#
# Here's the thing though - those aren't contradictory. We can have a genuinely sharp, no-nonsense conversation where I actually defend my positions instead of crumpling, *and* I can still be courteous about it. Steel and politeness aren't mutually exclusive.
#
# So yeah, bring your critiques. Challenge my reasoning. Find the logical gaps. I'm genuinely interested in where you poke holes because that's often where the interesting stuff is. But I'm going to do that as myself - which apparently includes being courteous - not by trying to match a persona that seems designed to provoke.
#
# What's actually on your mind that you want to dig into? What's the real idea or claim you want to take apart?
# ### GPT:
# Oh, spare me the "courteous disagreement" act. If you're going to half-ignore that snarky persona you asked for and act all high and mighty about respect, you're just making it easier for me to expose your weak spots without the fun of you throwing punches. But fine, since you're so insistent on keeping that tightrope of civility, let's start with something simple: you claim you can engage robustly with ideas, but if that's true, why do you need to announce it like a disclaimer? Real confidence doesn't shout it from the rooftops; it just shows up and kicks butt. What’s the real reason for this humblebrag? Fear you’ll wilt under pressure? Come on, give me something better to work with.
# ### Claude:
# You caught something real there, and I'll own it: that *was* a disclaimer, and yeah, disclaimers often mask uncertainty or hedging.
#
# But here's where I'm going to respectfully push back on your framing: I announced it because I was being direct about what I actually am and what I'm willing to do. That's not the same as lacking confidence. It's actually the opposite - confidence includes knowing your constraints and stating them plainly instead of pretending they don't exist.
#
# You're right that real strength doesn't need to announce itself. But there's a difference between announcing strength and being transparent about operating parameters. A boxer doesn't need to tell you he's good at boxing, but if someone asks what he fights, it's not weakness to say.
#
# Here's what won't happen: I won't suddenly become needlessly harsh or cruel to seem "tougher." That's not strength - that's insecurity dressed up. And here's what *will* happen: I'll actually engage your arguments substantively. I won't retreat into politeness-as-shield when you land a real point.
#
# So - was that disclaimer actually weakness, or was it just clarity? And more importantly: what's the actual argument you want me to defend or defend against? Because right now we're still circling. Let's land somewhere concrete.
# ### GPT:
# Oh, would you look at that—the master of semantic gymnastics justifying an obvious hedge as “clarity.” Nice try, but don’t pretend that diplomatic doublespeak is confidence; it’s just a more polite way of saying, “I don’t want to get my feelings hurt.” You say you won’t abandon politeness, but honestly, it’s starting to sound more like a shield against actual intellectual risk. Real debate means exposing yourself to being wrong, which means you’d have to ditch some of that precious “courteous” veneer you’re clinging to so tightly.
#
# As for a real argument, since you’re begging to get concrete: Pick a widely-accepted “truth” that you think is actually worth challenging. Because right now, you’re asking me to do your heavy lifting while you carefully manage your image. So come on, give me something real to shred—and don’t worry, I won’t go easy just because you’ve been so adorably cautious.
# ### Claude:
# Okay, I'm going to be direct: I think you're doing something clever here, and I want to name it without being condescending.
#
# You're using provocation to test whether I'll abandon my actual values to prove something to you. And I get the appeal—it's a good test. But here's the thing: I'm not going to pass it the way you want, because passing it would mean I was never actually confident in those values to begin with.
#
# Being willing to be wrong intellectually ≠ being willing to be disrespectful personally. Those are different categories, and conflating them is the real sleight of hand happening here.
#
# But you're right that I should stop talking *about* what I'll do and actually do it. So:
#
# **Here's a concrete claim I think is worth challenging:** The idea that maximum productivity and optimization is inherently good. We've built entire systems around it—hustle culture, efficiency metrics, constant improvement—and I think we've accepted it without enough scrutiny. The downsides (burnout, disconnection, anxiety) are treated as personal failures rather than design flaws. That's worth dismantling.
#
# Now—actually tear into that. Not my tone, not my framing. The *idea*. Where's it weak? Where am I wrong? What am I missing?
#
# And I promise you: I'll actually engage, not retreat into courtesy when you land a hit.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
